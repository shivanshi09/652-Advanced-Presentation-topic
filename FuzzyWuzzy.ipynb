# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import math
import pandas as pd
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Example 1
# Simplest ratio
# There are sequence Matching is a bit slow so we can install Levenshetein library to make this process go a bit faster
print(fuzz.ratio("Hello World!", "Helloworld"))
# Out:
# 82

# %%
# Example 2
# Token Sort Ratio
simple = fuzz.ratio("This ratio isn't that diffferent", "This ratio isn't ReAlly tHaT DifFerent")
print(simple)
sort = fuzz.token_sort_ratio("This ratio isn't that diffferent", "ratio This isn't tHaT DifFerent ReAlly")
print(sort)
# Out:
# 77
# 89

# %%
#Example 3
print(fuzz.token_sort_ratio("fuzzy was a bear", "fuzzy fuzzy was a bear"))
print(fuzz.token_set_ratio("fuzzy was a bear", "fuzzy fuzzy was a bear"))
# Out:
# 84
# 100

# %%
choices = ["Pepperoni Pizza, Cheese Pizza, Double Cheeseburger, Italian Hotdogs"]
print(process.extract("pizza", choices, limit=2))

process.extractOne("cheese", choices)
# Out:
# [('Pepperoni Pizza, Cheese Pizza, Double Cheeseburger, Italian Hotdogs', 60)]
# ('Pepperoni Pizza, Cheese Pizza, Double Cheeseburger, Italian Hotdogs', 60)

# %% [markdown]
# Demonstration of the FuzzyWuzzy library in the Online Travel Agency (OTA). OTA like Expedia and Booking.com denote a room in the same hotel with different nomenclature. For example, one room in the same hotel is called 'Studio, 1 King Bed with Sofa bed, Corner' by Expedia while Booking.com may show it as 'Corner King Studio'. This can create confusion for the customers when they are comparing room rate between OTAs or specifically comparing prices of a room at two different OTAs.

# %% [markdown]
# One of the most consistently frustating issues for price comparison websites and app is trying to figure out whether two items (or hotel rooms) are for the same thing, automatically. We are using the dataset of the room types from two Online Travel Agencies Expedia and Booking.com. Using this dataset, we would implement FuzzyWuzzy to match records of the room type between two OTAs.

# %%
# read the room_type data in pandas dataframe
room_type = pd.read_csv('room_type.csv')

# %%
# view the data
room_type.head()
# Out:
#                                  Expedia  \
# 0                Deluxe Room, 1 King Bed
# 1  Standard Room, 1 King Bed, Accessible
# 2     Grand Corner King Room, 1 King Bed
# 3             Suite, 1 King Bed (Parlor)
# 4    High-Floor Premium Room, 1 King Bed
#
#                                Booking.com
# 0                         Deluxe King Room
# 1  Standard King Roll-in Shower Accessible
# 2                   Grand Corner King Room
# 3                        King Parlor Suite
# 4             High-Floor Premium King Room

# %%
# analysing which function gives us the precise results for string matching between room types

# using the ratio function to check the similarity 
fuzz.ratio('Deluxe Room, 1 King Bed','Deluxe King Room')
# Out:
# 62

# %% [markdown]
# This shows that the 'Deluxe Room, 1 King Bed' and 'Deluxe King Room' are about 62% similar

# %%
# lets check another pair
fuzz.ratio('Room, 2 Double Beds (19th to 25th Floors)', 'Two Double Beds - Location Room (19th to 25th Floors)')
# Out:
# 74

# %% [markdown]
# This shows that 'Room, 2 Double Beds (19th to 25th Floors)'and 'Two Double Beds - Location Room (19th to 25th Floors)' are 74% similar. It seems that this naive approach is far too sensitive to minor differences in word order, missing or extra words and other. So we should choose function that ignores word order, duplicated words and be little bit more flexible. So we choose to use the token_set_ratio to find the optimized string match results

# %%
# create a function that takes the dataset and 
# compare the room_type in Expedia to that of Booking.com to find the similarity value

def similarity_ratio (row):
    room_name1 = row['Expedia']
    room_name2 = row['Booking.com']
    similarity = fuzz.token_set_ratio(room_name1, room_name2) # compute the match score between expedia and booking.com room type
    return similarity # return the similarity score

# %%
# append column similarity to room_type dataframe
room_type['similarity'] = room_type.apply(similarity_ratio,axis = 1)

# %%
# view the dataframe with the similarity ratio
room_type
# Out:
#                                                Expedia  \
# 0                              Deluxe Room, 1 King Bed
# 1                Standard Room, 1 King Bed, Accessible
# 2                   Grand Corner King Room, 1 King Bed
# 3                           Suite, 1 King Bed (Parlor)
# 4                  High-Floor Premium Room, 1 King Bed
# 5               Traditional Double Room, 2 Double Beds
# 6                         Room, 1 King Bed, Accessible
# 7                              Deluxe Room, 1 King Bed
# 8                                          Deluxe Room
# 9            Room, 2 Double Beds (19th to 25th Floors)
# 10                Room, 1 King Bed (19th to 25 Floors)
# 11                                         Deluxe Room
# 12              Junior Suite, 1 King Bed with Sofa Bed
# 13                        Signature Room, 2 Queen Beds
# 14                          Signature Room, 1 King Bed
# 15                          Premium Room, 2 Queen Beds
# 16            Studio, 1 King Bed with Sofa bed, Corner
# 17                             Club Room, 2 Queen Beds
# 18                               Club Room, 1 King Bed
# 19                     Club Room, Premium 2 Queen Beds
# 20                                    Suite, 1 Bedroom
# 21                              Deluxe Room, City View
# 22                              Deluxe Room, Lake View
# 23   Club Room, City View (Club Lounge Access for 2...
# 24   Club Room, Lake View (Club Lounge Access for 2...
# 25                             Deluxe Room, 1 King Bed
# 26                           Deluxe Room, 2 Queen Beds
# 27               Premier Room, 1 King Bed (Royal Club)
# 28                    Room, 2 Double Beds, Non Smoking
# 29             Room, 1 King Bed, Non Smoking (LEISURE)
# ..                                                 ...
# 73                           Standard Room, Ocean View
# 74                           Standard Room, Oceanfront
# 75                                City Room, City View
# 76                            Room, Partial Ocean View
# 77                                 Deluxe Room, Corner
# 78                                    Room, Ocean View
# 79                         Room, 1 King Bed, City View
# 80                      Room, 2 Double Beds, City View
# 81             Room, 2 Double Beds, Partial Ocean View
# 82   Room, 2 Double Beds, Accessible, Partial Ocean...
# 83      Room, 2 Double Beds, Ocean View (Diamond Head)
# 84                   Club Room, 1 King Bed, Oceanfront
# 85      Club Suite, 1 King Bed, Accessible, Ocean View
# 86   Club Suite, 1 King Bed, Oceanfront (No Resort ...
# 87   Standard Room, Mountain View (City View - Kona...
# 88   Standard Room, Partial Ocean View (Kona Tower)...
# 89   Standard Room, Partial Ocean View (Waikiki Tow...
# 90   Standard Room, Ocean View (Waikiki Tower) - No...
# 91                   Room, 2 Queen Beds (Waikiki View)
# 92                                    Room, Ocean View
# 93                                    Room, Oceanfront
# 94                         Regency Club, Mountain View
# 95                            Regency Club, Ocean View
# 96                        Room, 1 King Bed, Ocean View
# 97                Room, 1 King Bed, Resort View (Alii)
# 98   Room, 1 King Bed, Accessible, Resort View (Ali...
# 99   Room, 1 King Bed, Accessible, View (Rainbow, B...
# 100                Room, 1 King Bed, Ocean View (Alii)
# 101             Room, 1 King Bed, Oceanfront (Rainbow)
# 102  Junior Suite, 1 King Bed, Accessible (Roll-in ...
#
#                                            Booking.com  similarity
# 0                                     Deluxe King Room         100
# 1              Standard King Roll-in Shower Accessible          81
# 2                               Grand Corner King Room         100
# 3                                    King Parlor Suite         100
# 4                         High-Floor Premium King Room         100
# 5                     Double Room with Two Double Beds          78
# 6                        King Room - Disability Access          72
# 7                                     Deluxe King Room         100
# 8                         Deluxe Room (Non Refundable)         100
# 9    Two Double Beds - Location Room (19th to 25th ...          97
# 10      King Bed - Location Room (19th to 25th Floors)          92
# 11                                  Deluxe Double Room         100
# 12                                        Junior Suite         100
# 13                                 Signature Two Queen          88
# 14                                  Signature One King          88
# 15                                   Premium Two Queen          87
# 16                                  Corner King Studio         100
# 17                                      Club Two Queen          83
# 18                                       Club One King          82
# 19                              Club Premium Two Queen          90
# 20                                   One Bedroom Suite          93
# 21                           Deluxe King Or Queen Room          69
# 22            Deluxe King Or Queen Room with Lake View         100
# 23        Club Level King Or Queen Room with City View          64
# 24       Club Level King Or Queen Room with Water View          55
# 25                          Deluxe Room - One King Bed          95
# 26                        Deluxe Room - Two Queen Beds          96
# 27              Royal Club Premier Room - One King Bed          97
# 28                    Double Room with Two Double Beds          78
# 29                                           King Room         100
# ..                                                 ...         ...
# 73                       Standard Room With Ocean View         100
# 74                 Standard Room With Ocean Front View          70
# 75                                 Room With City View         100
# 76                            Partical Ocean View Room          98
# 77                                Corner Deluxe Studio          84
# 78                                Room With Ocean View         100
# 79                         City View With One King Bed          84
# 80                      City View With Two Double Beds          86
# 81             Partial Ocean View With Two Double Beds          90
# 82   Accessible Partial Ocean View With Two Double ...          92
# 83   Club Diamond Head Ocean View With Two Double Beds          91
# 84                  Club Ocean Front With One King Bed          71
# 85   Accessible Club Ocean View Suite With One King...          98
# 86                     Club Ocean Front Suite King Bed          76
# 87                     Kona Tower City / Mountain View         100
# 88                       Kona Tower Partial Ocean View         100
# 89                    Waikiki Tower Partial Ocean View         100
# 90                            Waikiki Tower Ocean View         100
# 91     Queen Room With Two Queen Beds and Waikiki View          97
# 92              King Or Two Queen Room With Ocean View         100
# 93                One King Or Two Queens - Ocean Front          33
# 94                          Regency Club Mountain View         100
# 95                             Regency Club Ocean View         100
# 96                       Ocean View Room With King Bed          96
# 97                Alii Tower Resort View With King Bed          88
# 98   Alii Tower Resort View With King Bed - Mobilit...          83
# 99   Rainbow Tower Ocean View With King Bed - Mobil...          81
# 100                Alii Tower Ocean View With King Bed          87
# 101            Rainbow Tower Ocean Front with King Bed          68
# 102           Junior Suite - Accessible Roll-in Shower         100
#
# [103 rows x 3 columns]

# %%
# compute the percentage of the pairs exceeding a match score of 70
similarity_percent = len(room_type[room_type.apply(similarity_ratio, axis = 1) > 70])/len(room_type)*100

# %%
similarity_percent
# Out:
# 90.29126213592234

# %%
print('Over ', math.floor(similarity_percent), '% of the pairs exceed a match score of 70 when setting ratio > 70')
# Out:
# Over  90 % of the pairs exceed a match score of 70 when setting ratio > 70
